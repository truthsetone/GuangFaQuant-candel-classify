# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
a=pd.read_excel("van_factor_2007-01-01.xlsx")
a=a['0']
a.skew(axis=0)
# Out:
# 0.37402991113876694

# %%
plt.hist(a,bins=20)
# Out:
# (array([1.8300e+03, 1.0259e+04, 2.7166e+04, 5.0301e+04, 7.3313e+04,
#         8.7968e+04, 9.1686e+04, 8.6859e+04, 7.4559e+04, 5.9804e+04,
#         4.3914e+04, 3.0002e+04, 1.8850e+04, 1.0643e+04, 5.4020e+03,
#         2.4370e+03, 9.5600e+02, 2.9600e+02, 5.2000e+01, 9.0000e+00]),
#  array([0.0093  , 0.052505, 0.09571 , 0.138915, 0.18212 , 0.225325,
#         0.26853 , 0.311735, 0.35494 , 0.398145, 0.44135 , 0.484555,
#         0.52776 , 0.570965, 0.61417 , 0.657375, 0.70058 , 0.743785,
#         0.78699 , 0.830195, 0.8734  ]),
#  <BarContainer object of 20 artists>)

# %%
b=pd.read_excel("test_factor_2007-01-01.xlsx")
b_temp=b['0']
b_temp.skew(axis=0)
# Out:
# 0.3667434221529277

# %%
plt.hist(b_temp,bins=20)
# Out:
# (array([2.07600e+03, 1.14920e+04, 2.95460e+04, 5.59420e+04, 8.10460e+04,
#         9.90030e+04, 1.05185e+05, 1.01518e+05, 8.83080e+04, 7.05380e+04,
#         5.21790e+04, 3.58380e+04, 2.23950e+04, 1.30990e+04, 6.84100e+03,
#         3.19600e+03, 1.32200e+03, 4.54000e+02, 1.06000e+02, 9.00000e+00]),
#  array([0.0119 , 0.05488, 0.09786, 0.14084, 0.18382, 0.2268 , 0.26978,
#         0.31276, 0.35574, 0.39872, 0.4417 , 0.48468, 0.52766, 0.57064,
#         0.61362, 0.6566 , 0.69958, 0.74256, 0.78554, 0.82852, 0.8715 ]),
#  <BarContainer object of 20 artists>)
